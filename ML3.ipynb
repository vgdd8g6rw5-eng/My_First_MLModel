# %% [markdown]
# <a href="https://colab.research.google.com/github/vgdd8g6rw5-eng/My_First_MLModel/blob/main/ML3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import linear_model
df = pd.read_csv("project3.csv")
df
# Out:
#     age  experience  income
# 0    25         1.0   30450
# 1    30         3.0   35670
# 2    47         2.0   31580
# 3    32         5.0   40130
# 4    43        10.0   47830
# 5    51         7.0   41630
# 6    28         5.0   41340
# 7    33         4.0   37650
# 8    37         5.0   40250
# 9    39         8.0   45150
# 10   29         NaN   27840
# 11   47         9.0   46110
# 12   54         5.0   36720
# 13   51         4.0   34800
# 14   44        12.0   51300
# 15   41         6.0   38900
# 16   58        17.0   63600
# 17   23         1.0   30870
# 18   44         9.0   44190
# 19   37        10.0   48700

# %%
import math
median_experience = math.floor(df.experience.median())
median_experience
# Out:
# 5

# %%
df.experience = df.experience.fillna(median_experience)
df
# Out:
#     age  experience  income
# 0    25         1.0   30450
# 1    30         3.0   35670
# 2    47         2.0   31580
# 3    32         5.0   40130
# 4    43        10.0   47830
# 5    51         7.0   41630
# 6    28         5.0   41340
# 7    33         4.0   37650
# 8    37         5.0   40250
# 9    39         8.0   45150
# 10   29         5.0   27840
# 11   47         9.0   46110
# 12   54         5.0   36720
# 13   51         4.0   34800
# 14   44        12.0   51300
# 15   41         6.0   38900
# 16   58        17.0   63600
# 17   23         1.0   30870
# 18   44         9.0   44190
# 19   37        10.0   48700

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['age'], df['experience'], df['income'], c='blue')

ax.set_xlabel("Age")
ax.set_ylabel("Experience")
ax.set_zlabel("Income")

ax.plot_surface(AGE, EXP, INCOME_pred, alpha=0.20, linewidth=0, antialiased=True)

df['predicted_income'] = reg.predict(df[['age', 'experience']])
df['below_plane'] = df['income'] < df['predicted_income']
ax.scatter(
    df[df['below_plane']]['age'],
    df[df['below_plane']]['experience'],
    df[df['below_plane']]['income'],
    color='red',
    s=50,
    label='Below plane'
)

plt.show()

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['age', 'experience']],df.income)

# %%
x = reg.coef_[0]
y = reg.coef_[1]

print("Coefficient for age =", x)
print("Coefficient for experience  =", y)

# %%
reg.predict([[22, 4]])
